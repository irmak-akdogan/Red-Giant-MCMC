# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("refit_output/merged_refit.csv", index_col="KIC")

# %%
df
# Out:
#              nu_max              H              P           tau     alpha  \
# KIC
# 757137    30.374092    6051.454513   18853.554168  10553.290465  3.228548
# 892010    17.251069   24012.312930   75683.986322  15982.226840  3.483531
# 892738     7.315255  193409.940841  389353.384070  34712.292894  3.389870
# 892760    29.599490   20131.971346   66179.501626  13356.102818  2.714647
# 893214    40.233599    3267.076794   14197.422539  12963.744223  2.537239
# ...             ...            ...            ...           ...       ...
# 12884930  37.399050    7192.758154   24345.213299  12392.326954  2.567758
# 12885005  28.479695   26614.277615   78768.483771  12457.307714  2.892285
# 12885196  89.448084     778.452257    5379.959900   8468.346885  2.050317
# 12885373  51.397316    2983.907835   11562.005286   9832.191103  2.623065
# 12934574  30.289227   23354.871312   75657.141467  13931.624063  2.787407
#
#                    W  success  status
# KIC
# ...

# %%
plt.pie([df["success"].sum(), (~df["success"]).sum()], labels=["minimize converged", "minimize didnt converge"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fdcc3e163f0>,
# ...
#  [Text(-1.0998700255211216, 0.01690937491948272, 'minimize converged'),
#   Text(1.0998700258921768, -0.0169093507841871, 'minimize didnt converge')])

# %%
# feeling whimsical
